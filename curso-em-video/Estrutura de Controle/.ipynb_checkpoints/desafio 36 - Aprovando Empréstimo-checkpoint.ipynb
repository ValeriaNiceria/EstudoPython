# %% [markdown]
# # Desafio 36
# ## Aprovando Empréstimo

# %% [markdown]
# Escreva um programa para aprovar o empréstimo bancário para a compra de uma casa. Pergunte o **valor da casa**, o **salário** do comprador e em **quantos anos** ele vai pagar.
# A prestação mensal, não pode exceder **30%** do salário ou então o empréstimo será negado.

# %%
valor_casa = float(input('Informe o valor da casa: R$'))
salario = float(input('Informe o salário do comprador: R$'))
anos = int(input('Em quantos anos irá pagar:'))
# Out:
# Informe o valor da casa: R$90000
# Informe o salário do comprador: R$2400
# Em quantos anos irá pagar:10

# %%
meses = anos * 12
prestacao = valor_casa / meses
salario_minimo = salario * 30 / 100

print('Para pagar uma casa de R${:.2f} em {} anos, a prestação será de R${:.2f}.'.format(valor_casa, anos, prestacao))

if salario_minimo < prestacao:
    print('Empréstimo NEGADO!')
else:
    print('Empréstimo CONCEDIDO!')
# Out:
# Para pagar uma casa de R$90000.00 em 10 anos, a prestação será de R$750.00.
# Empréstimo NEGADO!
