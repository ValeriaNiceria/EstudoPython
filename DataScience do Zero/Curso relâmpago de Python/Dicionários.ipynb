# %% [markdown]
# # Dicionários

# %%
empty_dict = {} # Pythonic
empty_dict2 = dict() # menos Pythonic
grades = {"Joel": 80, "Tim": 95}

# %%
joel_grade = grades['Joel']

joel_grade
# Out:
# 80

# %%
try:
    kates_grade = grades['Kate']
except KeyError:
    print("no grade for Kate!")
# Out:
# no grade for Kate!

# %%
# Verificando a existência de uma chave usando in
joel_has_grade = "Joel" in grades
kate_has_grade = "Kate" in grades

# %%
joel_has_grade
# Out:
# True

# %%
kate_has_grade
# Out:
# False

# %%
# O método get retorna um valor padrão
joels_grade = grades.get('Joel', 0)
kates_grade = grades.get('Kate', 0)
no_ones_grade = grades.get("No One")

# %%
joels_grade
# Out:
# 80

# %%
kates_grade
# Out:
# 0

# %%
no_ones_grade

# %%
grades['Tim'] = 99 # Substitui o valor antigo
grades['Kim'] = 100 # adiciona uma terceira entrada
num_students = len(grades) # é igual a 3

# %%
tweet = {
    "user": "joelgrus",
    "text": "Data Science is Awesome",
    "retweet_count": 100,
    "hashtags": ['#data', '#science', '#datascience', '#awesome', '#yolo']
}

tweet
# Out:
# {'user': 'joelgrus',
#  'text': 'Data Science is Awesome',
#  'retweet_count': 100,
#  'hashtags': ['#data', '#science', '#datascience', '#awesome', '#yolo']}

# %%
tweet.keys()
# Out:
# dict_keys(['user', 'text', 'retweet_count', 'hashtags'])

# %%
tweet.values()
# Out:
# dict_values(['joelgrus', 'Data Science is Awesome', 100, ['#data', '#science', '#datascience', '#awesome', '#yolo']])

# %%
tweet.items()
# Out:
# dict_items([('user', 'joelgrus'), ('text', 'Data Science is Awesome'), ('retweet_count', 100), ('hashtags', ['#data', '#science', '#datascience', '#awesome', '#yolo'])])

# %%
"user" in tweet
# Out:
# True

# %%
"joelgrus" in tweet
# Out:
# False

# %%
"joelgrus" in tweet.values()
# Out:
# True
