# %% [markdown]
# # Strings

# %%
sigle_quoted_string = 'data science'
sigle_quoted_string
# Out:
# 'data science'

# %%
sigle_quoted_string = "Data Science"
sigle_quoted_string
# Out:
# 'Data Science'

# %% [markdown]
# > O Python usa a barra invertida para codificar caracteres especiais

# %%
tab_string = "\t" # representa o caractere tab
len(tab_string)
# Out:
# 1

# %%
not_tab_string = r"\t" # representa os caracteres '\' e 't'
len(not_tab_string)
# Out:
# 2

# %%
# Criando strings múltiplas usando aspas triplas ou duplas
multi_line_string = """ esta é a primeira linha.
e esta é a segunda
e esta é a terceira
"""

multi_line_string
# Out:
# ' esta é a primeira linha.\ne esta é a segunda\ne esta é a terceira\n'
