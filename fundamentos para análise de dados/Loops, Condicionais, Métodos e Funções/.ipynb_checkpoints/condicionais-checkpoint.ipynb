# %% [markdown]
# # Condicionais

# %%
# Codicional If
if 5 > 2:
    print('O valor 5 é maior que 2!')
# Out:
# O valor 5 é maior que 2!

# %%
# Statement If...Else
if 5 < 2:
    print('Python funciona!')
else:
    print('Algo está errado!')
# Out:
# Algo está errado!

# %%
if 5 == 5:
    print('Testando Python!')
# Out:
# Testando Python!

# %%
if True:
    print('Parece que Python funciona!')
# Out:
# Parece que Python funciona!
