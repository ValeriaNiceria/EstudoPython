# %% [markdown]
# # Condicionais Aninhadas

# %%
idade = 18
if idade >= 18:
    print('Você pode dirigir!')
# Out:
# Você pode dirigir!

# %%
nome = 'Bob'
if idade > 13:
    if nome == 'Bob':
        print('Ok Bob, você foi autorizado a entrar!')
else:
    print('Desculpe, mas você não pode entrar!')
# Out:
# Ok Bob, você foi autorizado a entrar!

# %%
idade = 13
if idade >= 13 and nome == 'Bob':
    print('Ok Bob, você foi autorizado a entrar!')
# Out:
# Ok Bob, você foi autorizado a entrar!

# %%
idade = 12
if (idade >= 13) or (nome == 'Bob'):
    print('Ok Bob, você foi autorizado a entrar!')
# Out:
# Ok Bob, você foi autorizado a entrar!

# %%
# Usando mais uma condição na cláusula if
disciplina = input('Digite o nome da disciplina: ')
nota_final = input('Digite a nota final (entre 0 e 100): ')

if disciplina == 'Geografia' and nota_final >= '70':
    print('Você foi aprovado!')
else:
    print('Lamento, acho que você precisa estudar mais!')
# Out:
# Digite o nome da disciplina: Matemática
# Digite a nota final (entre 0 e 100): 7
# Lamento, acho que você precisa estudar mais!

# %%
# Usando mais de uma condição na cláusula if e introduzindo Placeholders
disciplina = input('Digite o nome da disciplina: ')
nota_final = input('Digite a nota final (entre 0 e 100): ')
semestre = input('Digite o semestre (1 a 4): ')

if disciplina == 'Geografia' and nota_final >= '60' and int(semestre) != 1:
    print('Você foi aprovado em %s com média final %r!' %(disciplina, nota_final))
else:
    print('Lamento, acho que você precisa estudar mais!')
# Out:
# Digite o nome da disciplina: Geografia
# Digite a nota final (entre 0 e 100): 67
# Digite o semestre (1 a 4): 3
# Você foi aprovado em Geografia com média final '67'!

# %% [markdown]
# # Elif

# %%
dia = 'Terça'
if dia == 'Segunda':
    print('Hoje fará sol!')
else:
    print('Hoje vai chover!')
# Out:
# Hoje vai chover!

# %%
if dia == 'Segunda':
    print('Hoje fará sol!')
elif dia == 'Terça':
    print('Hoje vai chover!')
else:
    print('Sem previsão do tempo para o dia selecionado.')
# Out:
# Hoje vai chover!
