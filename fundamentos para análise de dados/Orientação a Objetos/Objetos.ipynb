# %% [markdown]
# # Objetos
# Em Python, tudo é objeto!

# %%
# Criando uma lista
lst_num = ["Data", "Science", "Academy", "Nota", 10, 10]

# %%
# A lista lst_num é um objeto, uma instância da classe lista em Python
type(lst_num)
# Out:
# list

# %%
lst_num.count(10)
# Out:
# 2

# %%
# Usando a função type, para verificar o tipo de um objeto
print(type(10))
print(type([]))
print(type(()))
print(type({}))
print(type('a'))
# Out:
# <class 'int'>
# <class 'list'>
# <class 'tuple'>
# <class 'dict'>
# <class 'str'>

# %%
# Criando um novo tipo de objeto chamado Carro
class Carro(object):
    pass

# Instância do Carro
palio = Carro()

print(type(palio))
# Out:
# <class '__main__.Carro'>

# %%
# Criando uma classe
class Estudantes:
    def __init__(self, nome, idade, nota):
        self.nome = nome
        self.idade = idade
        self.nota = nota

# %%
# Criando um objeto chamado Estudante1 a partir da classe Estudadntes
Estudante1 = Estudantes('Maria', 30, 5.7)

# %%
# Atributo da classe Estudante, utilizado por cada objeto criado a partir desta classe
Estudante1.nome
# Out:
# 'Maria'

# %%
# Atributo da classe Estudante, utilizado por cada objeto criado a partir desta classe
Estudante1.idade
# Out:
# 30

# %%
# Atributo da classe Estudante, utilizado por cada objeto criado a partir desta classe
Estudante1.nota
# Out:
# 5.7

# %%
# Criando uma classe
class Funcionarios:
    def __init__(self, nome, salario):
        self.nome = nome
        self.salario = salario
        
    def listFunc(self):
            print("O nome do funcionário é: {} e o salário é R${}".format(self.nome, self.salario))

# %%
# Criando um objeto chamado Estudante1 a partir da classe Estudantes
Func1 = Funcionarios('Obama', 20000)

# %%
# Usando o método da classe
Func1.listFunc()
# Out:
# O nome do funcionário é: Obama e o salário é R$20000

# %%
print('**** Usando atributos ****')
# Out:
# **** Usando atributos ****

# %%
hasattr(Func1, 'nome')
# Out:
# True

# %%
hasattr(Func1, 'salario')
# Out:
# True

# %%
setattr(Func1, 'salario', 4500)

# %%
# Usando novamente o método da classe
Func1.listFunc()
# Out:
# O nome do funcionário é: Obama e o salário é R$4500

# %%
hasattr(Func1, 'salario')
# Out:
# True

# %%
getattr(Func1, 'salario')
# Out:
# 4500

# %%
delattr(Func1, 'salario')

# %%
hasattr(Func1, 'salario')
# Out:
# False

# %%
# Usando novamente o método da classe
Func1.listFunc()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-36-8bb8d3c459e6> in <module>
#       1 # Usando novamente o método da classe
# ----> 2 Func1.listFunc()
#
# <ipython-input-21-e82acdabe987> in listFunc(self)
#       6
#       7     def listFunc(self):
# ----> 8             print("O nome do funcionário é: {} e o salário é R${}".format(self.nome, str(self.salario)))
#
# AttributeError: 'Funcionarios' object has no attribute 'salario'
