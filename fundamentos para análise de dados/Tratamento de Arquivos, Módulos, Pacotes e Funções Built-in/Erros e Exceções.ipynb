# %% [markdown]
# # Erros e Exceções

# %%
8 + 's'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-1-963470595b1e> in <module>
# ----> 1 8 + 's'
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'

# %%
# Exceção
try:
    8 + 's'
except TypeError:
    print('Operação não permitida')
# Out:
# Operação não permitida

# %%
# Criando uma função
def numDiv(num1, num2):
    resultado = num1 / num2
    print(resultado)

# %%
# Execução não gera erro
numDiv(10, 2)
# Out:
# 5.0

# %%
# Execução gera um erro
numDiv(10, 0)
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# <ipython-input-9-40e92b6b6e25> in <module>
#       1 # Execução gera um erro
# ----> 2 numDiv(10, 0)
#
# <ipython-input-7-d9bac4198b10> in numDiv(num1, num2)
#       1 # Criando uma função
#       2 def numDiv(num1, num2):
# ----> 3     resultado = num1 / num2
#       4     print(resultado)
#
# ZeroDivisionError: division by zero

# %%
# Tratando erro na função
def numDiv(num1, num2):
    try:
        resultado = num1 / num2
        print(resultado)
    except ZeroDivisionError:
        print('Operação não permitida')

# %%
# Executando novamente com o denominador 0
numDiv(10, 0)
# Out:
# Operação não permitida

# %%
# Utilizando try, except e else
try:
    f = open('arquivos/testandoerros.txt', 'w')
    f.write('Gravando no arquivo')
except IOError:
    print('Erro: arquivo não encontrado ou não pode ser salvo.')
else:
    print('Conteúdo gravado com sucesso!')
    f.close()
# Out:
# Conteúdo gravado com sucesso!

# %%
# Utilizando try, except e else
try:
    f = open('arquivos/testandoerros', 'r')
except IOError:
    print('Erro: arquivo não encontrado ou não pode ser lido.')
else:
    print('Conteúdo lido com sucesso!')
    f.close()
# Out:
# Erro: arquivo não encontrado ou não pode ser lido.

# %%
try:
    f = open('arquivos/testandoerros.txt', 'w')
    f.write('Gravando no arquivo')
except IOError:
    print('Erro: arquivo não encontrado ou não pode ser lido.')
else:
    print('Conteúdo lido com sucesso!')
    f.close()
finally:
    print('Comandos no bloco finally são sempre executados!')
# Out:
# Conteúdo lido com sucesso!
# Comandos no bloco finally são sempre executados!

# %%
def askint():
    try:
        val = int(input('Digite um número: '))
    except UnboundLocalError:
        print('Você não digitou um número!')
    finally:
        print('Obrigado!')
    print(val)

# %%
askint()
# Out:
# Digite um número:
# Obrigado!
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-21-cc291aa76c10> in <module>
# ----> 1 askint()
#
# <ipython-input-20-93b89de6fec1> in askint()
#       1 def askint():
#       2     try:
# ----> 3         val = int(input('Digite um número: '))
#       4     except UnboundLocalError:
#       5         print('Você não digitou um número!')
#
# ValueError: invalid literal for int() with base 10: ' '

# %%
def askint():
    try:
        val = int(input('Digite um número: '))
    except:
        print('Você não digitou um número!')
        val = int(input('Digite um número: '))
    finally:
        print('Obrigado!')
    print(val)

# %%
askint()
# Out:
# Digite um número: k
# Você não digitou um número!
# Digite um número: 10
# Obrigado!
# 10

# %%
def askint():
    while True:
        try:
            val = int(input('Digite um número: '))
        except:
            print('Você não digitou um número!')
            continue
        else:
            print('Obrigado por digitar um número!')
            break
        finally:
            print('Fim da execução!')
        print(val)

# %%
askint()
# Out:
# Digite um número: k
# Você não digitou um número!
# Fim da execução!
# Digite um número: g
# Você não digitou um número!
# Fim da execução!
# Digite um número: 9
# Obrigado por digitar um número!
# Fim da execução!

# %%
tuple = (1, 2, 3, 4, 5)
try: 
    tuple.append(6)
    for each in tuple:
        print(each)
except AttributeError as e:
    print('Error:', e)
except IOError as e:
    print('Error I/O:', e)
# Out:
# Error: 'tuple' object has no attribute 'append'
