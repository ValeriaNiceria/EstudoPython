# %% [markdown]
# # Variáveis de Operadores

# %%
var_teste = 1

# %%
var_teste
# Out:
# 1

# %%
print(var_teste)
# Out:
# 1

# %%
type(var_teste)
# Out:
# int

# %%
var_teste = 5.3

# %%
var_teste
# Out:
# 5.3

# %%
type(var_teste)
# Out:
# float

# %% [markdown]
# ## Declaração múltipla

# %%
pessoa1, pessoa2, pessoa3 = "Catarina", "Tereza", "Margarida"

# %%
pessoa1
# Out:
# 'Catarina'

# %%
pessoa2
# Out:
# 'Tereza'

# %%
pessoa3
# Out:
# 'Margarida'

# %%
fruta1 = fruta2 = fruta3 = "Maçã"

# %%
fruta1
# Out:
# 'Maçã'

# %%
fruta2
# Out:
# 'Maçã'

# %%
fruta3
# Out:
# 'Maçã'

# %% [markdown]
# ## Operações com variáveis

# %%
idade1 = 10

# %%
idade2 = 12

# %%
soma_idades = idade1 + idade2

# %%
soma_idades
# Out:
# 22

# %%
subtracao_idades = idade1 - idade2

# %%
subtracao_idades
# Out:
# -2

# %% [markdown]
# ## Concatenação de variáveis

# %%
nome = 'Valéria'

# %%
sobrenome = 'Nicéria'

# %%
fullName = nome + ' ' + sobrenome

# %%
fullName
# Out:
# 'Valéria Nicéria'
