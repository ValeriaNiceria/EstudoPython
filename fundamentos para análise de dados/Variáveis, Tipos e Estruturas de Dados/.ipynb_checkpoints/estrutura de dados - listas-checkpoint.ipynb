# %% [markdown]
# # Estrutura de dados - Listas

# %%
# Criando uma lista 
listaMercado = ['ovos, farinha, leite, laranjas']

# %%
# Imprimindo
print(listaMercado)
# Out:
# ['ovos, farinha, leite, laranjas']

# %%
# Criando outra lista
listaMercado2 = ['ovos', 'farinha', 'leite', 'laranjas']

# %%
# Imprimindo
print(listaMercado2)
# Out:
# ['ovos', 'farinha', 'leite', 'laranjas']

# %%
listaMercado[0]
# Out:
# 'ovos, farinha, leite, laranjas'

# %%
listaMercado2[0]
# Out:
# 'ovos'

# %%
# Criando lista
lista3 = [10, 15, 'mercado']

# %%
lista3
# Out:
# [10, 15, 'mercado']

# %%
item1 = lista3[0]
item2 = lista3[1]
item3 = lista3[2]

# %%
print(item1, item2, item3)
# Out:
# 10 15 mercado

# %% [markdown]
# ## Atualizando um item da lista

# %%
# Imprimindo um item a lista
listaMercado2[2]
# Out:
# 'leite'

# %%
# Atualizando um item da lista
listaMercado2[2] = 'chocolate'

# %%
listaMercado2
# Out:
# ['ovos', 'farinha', 'chocolate', 'laranjas']

# %% [markdown]
# ## Deletando um item da lista

# %%
# Deletando um item específico da lista
del listaMercado2[3]

# %%
listaMercado2
# Out:
# ['ovos', 'farinha', 'chocolate']

# %% [markdown]
# ## Lista de listas (listas aninhadas)
# * Listas de listas são matrizes em Python

# %%
# Criando uma lista de listas
listas = [[1, 2, 3], [10, 15, 14], [10.1, 8.7, 2.3]]

# %%
listas
# Out:
# [[1, 2, 3], [10, 15, 14], [10.1, 8.7, 2.3]]

# %%
a = listas[0]

# %%
a
# Out:
# [1, 2, 3]

# %%
b = a[0]

# %%
b
# Out:
# 1

# %% [markdown]
# ## Operações com listas

# %%
listas
# Out:
# [[1, 2, 3], [10, 15, 14], [10.1, 8.7, 2.3]]

# %%
a = listas[0][0]

# %%
a
# Out:
# 1

# %%
b = listas[0][2]

# %%
b
# Out:
# 3

# %%
c = listas[0][2] + 10

# %%
c
# Out:
# 13

# %%
d = 10

# %%
e = d * listas[2][0]

# %%
e
# Out:
# 101.0

# %% [markdown]
# ## Concatenando listas

# %%
lista1 = [34, 32, 56]

# %%
lista1
# Out:
# [34, 32, 56]

# %%
lista2 = [21, 90, 51]

# %%
lista2
# Out:
# [21, 90, 51]

# %%
# Concatenando listas
listaTotal = lista1 + lista2

# %%
listaTotal
# Out:
# [34, 32, 56, 21, 90, 51]

# %% [markdown]
# ## Operador 'in'

# %%
listaTest = [100, 2, -5, 3.4, 'teste']

# %%
# Verificando se o valor 10 pertence a lista
print(10 in listaTest)
# Out:
# False

# %%
# Verificando se o valor 100 pertence a lista

# %%
print(100 in listaTest)
# Out:
# True

# %% [markdown]
# ## Funções Built-in

# %%
# Comprimento da lista
len(listaTotal)
# Out:
# 6

# %%
# Função max() retorna o valor máximo da lista
max(listaTotal)
# Out:
# 90

# %%
# Função min() retorna o valor mínimo da lista
min(listaTotal)
# Out:
# 21

# %%
listaMercado2
# Out:
# ['ovos', 'farinha', 'chocolate']

# %%
# Adiciona um item à lista
listaMercado2.append('carne')

# %%
listaMercado2
# Out:
# ['ovos', 'farinha', 'chocolate', 'carne']

# %%
listaMercado2.count('carne')
# Out:
# 1

# %%
# lista vazia
a = []

# %%
a
# Out:
# []

# %%
type(a)
# Out:
# list

# %%
a.append(10)

# %%
a.append(50)

# %%
a
# Out:
# [10, 50]

# %%
oldList = [1, 2, 5, 10]

# %%
newList = []

# %%
# Copiando os itens de uma lista para outra
for item in oldList:
    newList.append(item)

# %%
newList
# Out:
# [1, 2, 5, 10]

# %%
c = [20, 30, 60, 70]

# %%
c
# Out:
# [20, 30, 60, 70]

# %%
c.count(20)
# Out:
# 1

# %%
cidades = ['Recife', 'Manaus', 'Salvador']

# %%
cidades
# Out:
# ['Recife', 'Manaus', 'Salvador']

# %%
cidades.extend(['Fortaleza', 'Palmas'])

# %%
cidades
# Out:
# ['Recife', 'Manaus', 'Salvador', 'Fortaleza', 'Palmas']

# %%
cidades.index('Salvador')
# Out:
# 2

# %%
cidades.index('Fortaleza')
# Out:
# 3

# %%
cidades.insert(2, 110)

# %%
cidades
# Out:
# ['Recife', 'Manaus', 110, 'Salvador', 'Fortaleza', 'Palmas']

# %%
cidades.remove(110)

# %%
cidades
# Out:
# ['Recife', 'Manaus', 'Salvador', 'Fortaleza', 'Palmas']

# %%
# Reverte a lista
cidades.reverse()

# %%
cidades
# Out:
# ['Palmas', 'Fortaleza', 'Salvador', 'Manaus', 'Recife']

# %%
x = [3, 4, 2, 1]

# %%
x
# Out:
# [3, 4, 2, 1]

# %%
# Ordena a lista
x.sort()

# %%
x
# Out:
# [1, 2, 3, 4]
