# %% [markdown]
# # Strings

# %%
frase = "Criando uma string em Python"

# %%
frase
# Out:
# 'Criando uma string em Python'

# %% [markdown]
# ## Imprimindo uma string

# %%
print(frase)
# Out:
# Criando uma string em Python

# %%
print('Criando \nString \nem \nPython')
# Out:
# Criando
# String
# em
# Python

# %% [markdown]
# ## Indexando Strings

# %%
# Primeiro elemento da string
frase[0]
# Out:
# 'C'

# %%
frase[1]
# Out:
# 'r'

# %%
frase[2]
# Out:
# 'i'

# %%
frase[1:]
# Out:
# 'riando uma string em Python'

# %%
frase[:3]
# Out:
# 'Cri'

# %%
frase[:]
# Out:
# 'Criando uma string em Python'

# %%
frase[-1]
# Out:
# 'n'

# %%
frase[:-1]
# Out:
# 'Criando uma string em Pytho'

# %%
frase[::1]
# Out:
# 'Criando uma string em Python'

# %%
frase[::2]
# Out:
# 'Cinouasrn mPto'

# %%
frase[::-1]
# Out:
# 'nohtyP me gnirts amu odnairC'

# %% [markdown]
# ## Funções Built-in de strings

# %%
frase
# Out:
# 'Criando uma string em Python'

# %%
frase.upper()
# Out:
# 'CRIANDO UMA STRING EM PYTHON'

# %%
frase.lower()
# Out:
# 'criando uma string em python'

# %%
frase.split()
# Out:
# ['Criando', 'uma', 'string', 'em', 'Python']

# %%
frase.split('y')
# Out:
# ['Criando uma string em P', 'thon']

# %% [markdown]
# ## Funções string

# %%
frase
# Out:
# 'Criando uma string em Python'

# %%
frase_minusculo = frase.lower()

# %%
frase_minusculo
# Out:
# 'criando uma string em python'

# %%
frase_minusculo.capitalize()
# Out:
# 'Criando uma string em python'

# %%
frase.count('a')
# Out:
# 2

# %%
frase.find('p')
# Out:
# -1

# %%
frase.islower()
# Out:
# False

# %%
frase.isspace()
# Out:
# False

# %%
frase.endswith('o')
# Out:
# False

# %% [markdown]
# ## Comparação strings

# %%
'python' == 'R'
# Out:
# False

# %%
'python' == 'python'
# Out:
# True
